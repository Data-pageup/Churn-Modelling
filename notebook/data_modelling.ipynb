# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv('../data/processed/cleaned_data.csv')

# %%
df.columns
# Out:
# Index(['surname', 'creditscore', 'geography', 'gender', 'age', 'tenure',
#        'balance', 'numofproducts', 'hascrcard', 'isactivemember',
#        'estimatedsalary', 'exited'],
#       dtype='str')

# %%
df.select_dtypes(include= 'object').columns
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15176\3318113904.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include= 'object').columns
# Index(['surname', 'geography', 'gender'], dtype='str')

# %%
# surename we can skip 

# geogrphy - it has no order . we use label encoding 
# gender - binary encoding

# %%
df.gender.unique()
# Out:
# <StringArray>
# ['Female', 'Male']
# Length: 2, dtype: str

# %%
df.gender = df.gender.map({"Female":1, "Male":0
                           })

# %%
df = pd.get_dummies(df,columns= [ 'geography'])

# %%
df
# Out:
#         surname  creditscore  gender  age  tenure    balance  numofproducts  \
# 0      Hargrave          619       1   42       2       0.00              1
# 1          Hill          608       1   41       1   83807.86              1
# 2          Onio          502       1   42       8  159660.80              3
# 3          Boni          699       1   39       1       0.00              2
# 4      Mitchell          850       1   43       2  125510.82              1
# ...         ...          ...     ...  ...     ...        ...            ...
# 9995   Obijiaku          771       0   39       5       0.00              2
# 9996  Johnstone          516       0   35      10   57369.61              1
# 9997        Liu          709       1   36       7       0.00              1
# 9998  Sabbatini          772       0   42       3   75075.31              2
# 9999     Walker          792       1   28       4  130142.79              1
#
# ...

# %%
# # now scaling 
# before that we have to split the df
X = df.drop(columns= ['surname','exited'])
y  = df['exited']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state= 42)

# %%
X_train.shape
# Out:
# (7000, 12)

# %%
y_train.shape
# Out:
# (7000,)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # models

# %%
#metrics 
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
# logistic regression

from sklearn.linear_model import LogisticRegressionCV

# %%
lrcv = LogisticRegressionCV(
    Cs=10,              # number of values of C to try
    cv=5,               # 5-fold cross-validation
    penalty='l2',       # regularization type
    solver='lbfgs',     # optimization algorithm
    max_iter=1000,      # increase iterations for convergence
    scoring='accuracy', # metric to optimize
    random_state=42
)

# %%
lrcv.fit(X_train,y_train)
# Out:
# e:\churn_modelling\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:2092: FutureWarning: The default value for l1_ratios will change from None to (0.0,) in version 1.10. From version 1.10 onwards, only array-like with values in [0, 1] will be allowed, None will be forbidden. To avoid this warning, explicitly set a value, e.g. l1_ratios=(0,).
#   warnings.warn(
# e:\churn_modelling\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:2123: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratios' and 'Cs' instead. Use l1_ratios=(0,) instead of penalty='l2', l1_ratios=(1,) instead of penalty='l1', l1_ratios set to floats between 0 and 1 instead of penalty='elasticnet', and Cs=(np.inf,) instead of penalty=None.
#   warnings.warn(
# ...

# %%
# predicting 
y_pred = lrcv.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
print(accuracy_score(y_pred,y_test))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      2416
#            1       0.55      0.19      0.29       584
#
#     accuracy                           0.81      3000
#    macro avg       0.69      0.58      0.59      3000
# weighted avg       0.78      0.81      0.77      3000
#
# 0.8126666666666666
# [[2325   91]
#  [ 471  113]]

# %%
# we can further train this data with different model to improvise the accuracy 
# also by looking at the confusion matrix we can say that our model predicted 91 won't leave but they left .
